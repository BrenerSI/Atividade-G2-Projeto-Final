# %% [markdown]
# # Análise de Chuvas e Deslizamentos no RJ\n## Introdução\nEste notebook apresenta análises exploratórias sobre chuvas e deslizamentos no Estado do Rio de Janeiro.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\ndf = pd.read_csv('../dados/simulacao_chuvas_deslizamentos_rj.csv')\ndf.head()

# %% [markdown]
# ## KPIs e Análises

# %%
total_chuva = df['chuva_mm'].sum()\nmedia_chuva = df['chuva_mm'].mean()\ntotal_deslizamentos = df['ocorrencias_deslizamento'].sum()\n\nprint(total_chuva)\nprint(media_chuva)\nprint(total_deslizamentos)
